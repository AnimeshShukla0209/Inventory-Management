# %% [markdown]
# ## Json is nothing but a dictionary

# %%
#This is our inventory
record = {1001: {'Name': "5 Star"         , "Price" : 10 , "Qn" : 1500},
          1002: {'Name': "Bar-One"        , "Price" : 20 , "Qn" : 1000 },
          1003: {'Name': "Candy"          , "Price" : 2  , "Qn" : 1000},
          1004: {'Name': "Chocolate Cake" , "Price" : 550, "Qn" : 8 },
          1005: {'Name': "Blueberry Cake" , "Price" : 650, "Qn" : 5 },
          1006: {'Name': "Muesli"         , "Price" : 288, "Qn" : 100 },
          1007: {'Name': "Fan"            , "Price" : 1300, "Qn" : 20 }}

# %%
#importing important libraries
import json
import time

#opening our Records file which contains the inventory
fd = open('Record.json','r')
js = fd.read()
fd.close()

sale = ""
COUPONS = ["WELCOME 50","FLAT 70","AAPKA 60"]

coupon = input("Enter coupon no if any : ")

if coupon == COUPONS[0]:

    #loading the data to a variable name record
    record = json.loads(js)

    #printing the Menu for the user to see the products in inventory
    print("--------------------MENU---------------------")
    for key in record.keys():
        print(key, record[key]['Name'], record[key]['Price'], record[key]['Qn'])
    print("---------------------------------------------")
    print('')

    #Getting user inputs such as name,phone,Id of product
    ui_name = input("Enter your Name :")
    ui_phone = input("Enter your phone no :")
    ui_gmail  = input("Enter your mail ID :")
    ui_pr = str(input("Enter product ID : "))
    ui_qn = int(input("Enter Quantity   : "))
    discount = record[ui_pr]["Price"] * 0.5

    print("---------------------------------------------")
    print('')

    #If we have enouogh quantity to provide the user
    if (record[ui_pr]["Qn"] >= ui_qn):
        print("Name      : ", record[ui_pr]["Name"])
        print("Price (Rs): ", record[ui_pr]["Price"],"Rs")
        print("Quantity  : ", ui_qn)
        print("---------------------------------------------")
        print("=============================================")
        print("Discount  : ",discount)
        print("---------------------------------------------")
        print("Billing   : ",record[ui_pr]["Price"])
        print("---------------------------------------------")
        print("            ",f"-{discount}")
        print("=============================================")
        print("Total bill :",record[ui_pr]["Price"]*ui_qn - discount)
        print("---------------------------------------------")
        record[ui_pr]['Qn'] = record[ui_pr]['Qn'] - ui_qn
        print('')
        print("---------------------------------------------")
        print("  Thanks for your order, Inventory Updated!  ")
        print("---------------------------------------------")    
        sale = '1'+","+ui_name+","+ui_gmail+","+ui_phone+","+ui_pr+","+record[ui_pr]["Name"]+","+str(ui_qn)+","+str(record[ui_pr]["Price"])+","+time.ctime()
    #If we do not have enough quantity
    else:

        print("Sorry!, We're not having enough product in our inventory ")
        print("We're only having " ,record[ui_pr]["Qn"] ,"Rs")
        print("---------------------------------------------")
        ch = str(input("Enter Y/y to purchase the product :"))
        #Asking if he/she wants Left quantity

        if (ch == "Y") or (ch == "y"):

            print("Name      : ", record[ui_pr]["Name"])
            print("Price (Rs): ", record[ui_pr]["Price"])
            print("Quantity  : ", ui_qn)
            print("---------------------------------------------")
            print("Discount  : ",discount)
            print("---------------------------------------------")
            print("Billing   : ",record[ui_pr]["Price"])
            print("---------------------------------------------")
            print("            ",f"-{discount}")
            print("=============================================")
            print("Total bill :",record[ui_pr]["Price"]*ui_qn - discount)
            print("---------------------------------------------")
            record[ui_pr]['Qn'] = record[ui_pr]['Qn'] - ui_qn
            print('')
            print("---------------------------------------------")
            print("  Thanks for your order, Inventory Updated!  ")
            print("---------------------------------------------")
            sale = '1'+","+ui_name+","+ui_gmail+","+ui_phone+","+ui_pr+","+record[ui_pr]["Name"]+","+record[ui_pr]["Qn"]+","+str(record[ui_pr]["Price"])+","+time.ctime()

            record[ui_pr]["Qn"] = 0
        else:
            print("Thanks ! , Visit next time ")
elif coupon == COUPONS[1]:

    #loading the data to a variable name record
    record = json.loads(js)

    #printing the Menu for the user to see the products in inventory
    print("--------------------MENU---------------------")
    for key in record.keys():
        print(key, record[key]['Name'], record[key]['Price'], record[key]['Qn'])
    print("---------------------------------------------")
    print('')

    #Getting user inputs such as name,phone,Id of product
    ui_name = input("Enter your Name :")
    ui_phone = input("Enter your phone no :")
    ui_gmail  = input("Enter your mail ID :")
    ui_pr = str(input("Enter product ID : "))
    ui_qn = int(input("Enter Quantity   : "))
    discount = record[ui_pr]["Price"] * 0.7

    print("---------------------------------------------")
    print('')

    #If we have enouogh quantity to provide the user
    if (record[ui_pr]["Qn"] >= ui_qn):
        print("Name      : ", record[ui_pr]["Name"])
        print("Price (Rs): ", record[ui_pr]["Price"],"Rs")
        print("Quantity  : ", ui_qn)
        print("---------------------------------------------")
        print("=============================================")
        print("Discount  : ",discount)
        print("---------------------------------------------")
        print("Billing   : ",record[ui_pr]["Price"])
        print("---------------------------------------------")
        print("            ",f"-{discount}")
        print("=============================================")
        print("Total bill :",record[ui_pr]["Price"]*ui_qn - discount)
        print("---------------------------------------------")
        record[ui_pr]['Qn'] = record[ui_pr]['Qn'] - ui_qn
        print('')
        print("---------------------------------------------")
        print("  Thanks for your order, Inventory Updated!  ")
        print("---------------------------------------------")    
        sale = '1'+","+ui_name+","+ui_gmail+","+ui_phone+","+ui_pr+","+record[ui_pr]["Name"]+","+str(ui_qn)+","+str(record[ui_pr]["Price"])+","+time.ctime()
    #If we do not have enough quantity
    else:

        print("Sorry!, We're not having enough product in our inventory ")
        print("We're only having " ,record[ui_pr]["Qn"] ,"Rs")
        print("---------------------------------------------")
        ch = str(input("Enter Y/y to purchase the product :"))
        #Asking if he/she wants Left quantity

        if (ch == "Y") or (ch == "y"):

            print("Name      : ", record[ui_pr]["Name"])
            print("Price (Rs): ", record[ui_pr]["Price"])
            print("Quantity  : ", ui_qn)
            print("---------------------------------------------")
            print("Discount  : ",discount)
            print("---------------------------------------------")
            print("Billing   : ",record[ui_pr]["Price"])
            print("---------------------------------------------")
            print("            ",f"-{discount}")
            print("=============================================")
            print("Total bill :",record[ui_pr]["Price"]*ui_qn - discount)
            print("---------------------------------------------")
            record[ui_pr]['Qn'] = record[ui_pr]['Qn'] - ui_qn
            print('')
            print("---------------------------------------------")
            print("  Thanks for your order, Inventory Updated!  ")
            print("---------------------------------------------")
            sale = '1'+","+ui_name+","+ui_gmail+","+ui_phone+","+ui_pr+","+record[ui_pr]["Name"]+","+record[ui_pr]["Qn"]+","+str(record[ui_pr]["Price"])+","+time.ctime()

            record[ui_pr]["Qn"] = 0
        else:
            print("Thanks ! , Visit next time ")

            #dumpiing record            
elif coupon == COUPONS[2]:

    #loading the data to a variable name record
    record = json.loads(js)

    #printing the Menu for the user to see the products in inventory
    print("--------------------MENU---------------------")
    for key in record.keys():
        print(key, record[key]['Name'], record[key]['Price'], record[key]['Qn'])
    print("---------------------------------------------")
    print('')

    #Getting user inputs such as name,phone,Id of product
    ui_name = input("Enter your Name :")
    ui_phone = input("Enter your phone no :")
    ui_gmail  = input("Enter your mail ID :")
    ui_pr = str(input("Enter product ID : "))
    ui_qn = int(input("Enter Quantity   : "))
    discount = record[ui_pr]["Price"] * 0.2

    print("---------------------------------------------")
    print('')

    #If we have enouogh quantity to provide the user
    if (record[ui_pr]["Qn"] >= ui_qn):
        print("Name      : ", record[ui_pr]["Name"])
        print("Price (Rs): ", record[ui_pr]["Price"],"Rs")
        print("Quantity  : ", ui_qn)
        print("---------------------------------------------")
        print("=============================================")
        print("Discount  : ",discount)
        print("---------------------------------------------")
        print("Billing   : ",record[ui_pr]["Price"])
        print("---------------------------------------------")
        print("            ",f"-{discount}")
        print("=============================================")
        print("Total bill :",record[ui_pr]["Price"]*ui_qn - discount)
        print("---------------------------------------------")
        record[ui_pr]['Qn'] = record[ui_pr]['Qn'] - ui_qn
        print('')
        print("---------------------------------------------")
        print("  Thanks for your order, Inventory Updated!  ")
        print("---------------------------------------------")    
        sale = '1'+","+ui_name+","+ui_gmail+","+ui_phone+","+ui_pr+","+record[ui_pr]["Name"]+","+str(ui_qn)+","+str(record[ui_pr]["Price"])+","+time.ctime()
    #If we do not have enough quantity
    else:

        print("Sorry!, We're not having enough product in our inventory ")
        print("We're only having " ,record[ui_pr]["Qn"] ,"Rs")
        print("---------------------------------------------")
        ch = str(input("Enter Y/y to purchase the product :"))
        #Asking if he/she wants Left quantity

        if (ch == "Y") or (ch == "y"):

            print("Name      : ", record[ui_pr]["Name"])
            print("Price (Rs): ", record[ui_pr]["Price"])
            print("Quantity  : ", ui_qn)
            print("---------------------------------------------")
            print("Discount  : ",discount)
            print("---------------------------------------------")
            print("Billing   : ",record[ui_pr]["Price"])
            print("---------------------------------------------")
            print("            ",f"-{discount}")
            print("=============================================")
            print("Total bill :",record[ui_pr]["Price"]*ui_qn - discount)
            print("---------------------------------------------")
            record[ui_pr]['Qn'] = record[ui_pr]['Qn'] - ui_qn
            print('')
            print("---------------------------------------------")
            print("  Thanks for your order, Inventory Updated!  ")
            print("---------------------------------------------")
            sale = '1'+","+ui_name+","+ui_gmail+","+ui_phone+","+ui_pr+","+record[ui_pr]["Name"]+","+record[ui_pr]["Qn"]+","+str(record[ui_pr]["Price"])+","+time.ctime()

            record[ui_pr]["Qn"] = 0
        else:
            print("Thanks ! , Visit next time ")
else:
    print("You do not have a valid COUPON CODE")
    print("Shop more to have a coupon code")

    #loading the data to a variable name record
    record = json.loads(js)

    #printing the Menu for the user to see the products in inventory
    print("--------------------MENU---------------------")
    for key in record.keys():
        print(key, record[key]['Name'], record[key]['Price'], record[key]['Qn'])
    print("---------------------------------------------")
    print('')

    #Getting user inputs such as name,phone,Id of product
    ui_name = input("Enter your Name :")
    ui_phone = input("Enter your phone no :")
    ui_gmail  = input("Enter your mail ID :")
    ui_pr = str(input("Enter product ID : "))
    ui_qn = int(input("Enter Quantity   : "))

    print("---------------------------------------------")
    print('')

    #If we have enouogh quantity to provide the user
    if (record[ui_pr]["Qn"] >= ui_qn):
        print("Name      : ", record[ui_pr]["Name"])
        print("Price (Rs): ", record[ui_pr]["Price"],"Rs")
        print("Quantity  : ", ui_qn)
        print("---------------------------------------------")
        print("=============================================")
        print("Billing   : ", record[ui_pr]["Price"] * ui_qn )
        print("---------------------------------------------")
        record[ui_pr]['Qn'] = record[ui_pr]['Qn'] - ui_qn
        print('')
        print("---------------------------------------------")
        print("  Thanks for your order, Inventory Updated!  ")
        print("---------------------------------------------")    
        sale = '1'+","+ui_name+","+ui_gmail+","+ui_phone+","+ui_pr+","+record[ui_pr]["Name"]+","+str(ui_qn)+","+str(record[ui_pr]["Price"])+","+time.ctime()
    #If we do not have enough quantity
    else:

        print("Sorry!, We're not having enough product in our inventory ")
        print("We're only having " ,record[ui_pr]["Qn"] ,"Rs")
        print("---------------------------------------------")
        ch = str(input("Enter Y/y to purchase the product :"))
        #Asking if he/she wants Left quantity

        if (ch == "Y") or (ch == "y"):

            print("Name      : ", record[ui_pr]["Name"])
            print("Price (Rs): ", record[ui_pr]["Price"])
            print("Quantity  : ", ui_qn)
            print("---------------------------------------------")
            print("=============================================")
            print("Billing   : ", record[ui_pr]["Price"] * ui_qn )
            record[ui_pr]['Qn'] = record[ui_pr]['Qn'] - ui_qn
            print('')
            print("---------------------------------------------")
            print("  Thanks for your order, Inventory Updated!  ")
            print("---------------------------------------------")
            sale = '1'+","+ui_name+","+ui_gmail+","+ui_phone+","+ui_pr+","+record[ui_pr]["Name"]+","+record[ui_pr]["Qn"]+","+str(record[ui_pr]["Price"])+","+time.ctime()

            record[ui_pr]["Qn"] = 0
        else:
            print("Thanks ! , Visit next time ")

            #dumpiing record
            
#dumpiing record
js = json.dumps(record)

#updating inventory 
fd = open('Record.json','w')
fd.write(js)
fd.close()

# Adding Transaction on Sales File
fd = open('Sales.txt','a')
fd.write(sale)
fd.close()
print("------------------------------------------------------")
print("Hope you visit again!!!!!")
print("------------------------------------------------------")
# Out:
# Enter coupon no if any : FLAT 70
# --------------------MENU---------------------
# 1001 5 Star 10 978
# 1002 Bar-One 20 1000
# 1003 Candy 2 1000
# 1004 Chocolate Cake 550 5
# 1005 Blueberry Cake 650 5
# ---------------------------------------------
#
# Enter your Name :Animesh Shukla
# Enter your phone no :7999785780
# Enter your mail ID :AnimeshSHukla0209@gmail.com
# Enter product ID : 1001
# Enter Quantity   : 1
# ---------------------------------------------
#
# Name      :  5 Star
# Price (Rs):  10 Rs
# Quantity  :  1
# ---------------------------------------------
# ...
# Discount  :  7.0
# Billing   :  10
#              -7.0
# Total bill : 3.0
# ---------------------------------------------
#
# ---------------------------------------------
#   Thanks for your order, Inventory Updated!
# ---------------------------------------------
# ------------------------------------------------------
# Hope you visit again!!!!!
# ------------------------------------------------------
